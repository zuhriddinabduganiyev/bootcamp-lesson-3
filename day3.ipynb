# %% [markdown]
# # 3-VAZIFA

# %%
import pandas as pd

# %% [markdown]
# #### 3.1 WORLD POPULATION table ni saytdan olib quyidagi kod orqali ya'ni .read_csv() orqali csv faylini ochdim.

# %%
df = pd.read_csv("world_population.csv")
df
# Out:
#      Rank CCA3  Country/Territory           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %% [markdown]
# #### 3.2 Quyidagi kodda .head() metodi orqali boshidagi 5ta qatorini ko'rish uchun ishlatdim. Bu ma'lumotlar to'plamini boshlang'ich qismiga tezda nazar tashlash uchun juda foydali.

# %%
df.head()
# Out:
#    Rank CCA3 Country/Territory           Capital Continent  2022 Population  \
# 0    36  AFG       Afghanistan             Kabul      Asia         41128771
# 1   138  ALB           Albania            Tirana    Europe          2842321
# 2    34  DZA           Algeria           Algiers    Africa         44903225
# 3   213  ASM    American Samoa         Pago Pago   Oceania            44273
# 4   203  AND           Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# 4            77700            71746            71519            66097
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %% [markdown]
# #### 3.3 Quyidagi kodda .median() metodidan foydalandim bu metod DataFrame obyektidagi "World Population Percentage" ustunini medianini hisoblab berdi. World Population Percentagening mediani 0.07ga teng ekan.

# %%
df["World Population Percentage"].median()
# Out:
# 0.07

# %% [markdown]
# #### 3.4 Quyidagi kodda asia o'zgaruvchisiga "Continent" columdagi qiymatlardan faqat "Asia"ga teng bo'lganlarini filtrlab oldim.

# %%
asia = df["Continent"]=="Asia"
asia = df[asia]
asia
# Out:
#      Rank CCA3     Country/Territory              Capital Continent  \
# 0      36  AFG           Afghanistan                Kabul      Asia
# 9     140  ARM               Armenia              Yerevan      Asia
# 13     91  AZE            Azerbaijan                 Baku      Asia
# 15    154  BHR               Bahrain               Manama      Asia
# 16      8  BGD            Bangladesh                Dhaka      Asia
# 23    165  BTN                Bhutan              Thimphu      Asia
# 29    175  BRN                Brunei  Bandar Seri Begawan      Asia
# 33     73  KHM              Cambodia           Phnom Penh      Asia
# 41      1  CHN                 China              Beijing      Asia
# 73    131  GEO               Georgia              Tbilisi      Asia
# 89    104  HKG             Hong Kong            Hong Kong      Asia
# 92      2  IND                 India            New Delhi      Asia
# 93      4  IDN             Indonesia              Jakarta      Asia
# ...

# %% [markdown]
# #### 3.5 Quyidagi kod World Population Percentage ustunining eng ko'p uchraydigan qiymatini topadi. Natijani mode_value o'zgaruvchisida saqlaydi va ekranga chiqaradi.

# %%
mode_value = df['World Population Percentage'].mode()
mode_value
# Out:
# 0    0.0
# Name: World Population Percentage, dtype: float64

# %% [markdown]
# #### 3.6 Quyidagi kod 2022 yildagi eng kam aholi sonini chiqarib beradi.

# %%
min_population = df["2022 Population"].min()
min_population
# Out:
# 510

# %% [markdown]
# #### 3.7 Quyidagi kod 2022 yildagi eng kam aholisi bor davlatni nomini chiqaradi.

# %%
df[df["2022 Population"] == min_population]["Country/Territory"].values[0]
# Out:
# 'Vatican City'

# %% [markdown]
# #### 3.8 Quyidagi kod 2020 yildagi eng ko'p aholi sonini chiqarib beradi.

# %%
max_population = df["2020 Population"].max()
max_population
# Out:
# 1424929781

# %% [markdown]
# #### 3.9 Quyidagi kod 2020 yildagi eng ko'p aholisi bor davlatni nomini chiqaradi.

# %%
df[df["2020 Population"] == max_population]["Country/Territory"].values[0]
# Out:
# 'China'

# %% [markdown]
# #### 3.10 Quyidagi kod 2015 Population ustunining dispersiyasini hisoblab chiqarib beradi.

# %%
df["2015 Population"].var()
# Out:
# 1.7005462134586562e+16

# %%
df[["Area (km²)",]].std()
# Out:
# Area (km²)    1.761841e+06
# dtype: float64

# %% [markdown]
# #### 3.12 Quyidagi kod 2000 yilda aholi sonini hisoblab beradi.

# %%
df["2000 Population"].sum()
# Out:
# 6147055703

# %% [markdown]
# #### 3.13 Quyidagi kod ustun nomlari, ustunlarning turi, har bir ustundagi qiymatlar soni va xotira hajmi haqida ma'lumot beradi.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country/Territory            234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              234 non-null    int64
#  6   2020 Population              234 non-null    int64
#  7   2015 Population              234 non-null    int64
#  8   2010 Population              234 non-null    int64
#  9   2000 Population              234 non-null    int64
#  10  1990 Population              234 non-null    int64
#  11  1980 Population              234 non-null    int64
#  12  1970 Population              234 non-null    int64
# ...

# %% [markdown]
# #### 3.14 Quyidagi kod raqamli ustunlar uchun hisoblaydi soni (count), o'rtacha (mean), standart og'ish (std), minimum (min), 25%, 50%, va 75% kvantillar (25%, 50%, 75%), va maksimum (max) larni

# %%
df["Growth Rate"].describe()
# Out:
# count    234.000000
# mean       1.009577
# std        0.013385
# min        0.912000
# 25%        1.001775
# 50%        1.007900
# 75%        1.016950
# max        1.069100
# Name: Growth Rate, dtype: float64

# %% [markdown]
# #### 3.15 Quyidagi kod ustun yoki qatorning unikal qiymatlari va ularga teng bo'lgan qancha marta takrorlanganligini hisoblaydi va natijani Series ko'rinishida qaytaradi.

# %%
df["Area (km²)"].value_counts()
# Out:
# Area (km²)
# 21        2
# 652230    1
# 462840    1
# 923768    1
# 260       1
#          ..
# 108889    1
# 78        1
# 245857    1
# 36125     1
# 390757    1
# Name: count, Length: 233, dtype: int64

# %% [markdown]
# #### Bu kodda groupby() usuli orqali Continent ustuni bo'yicha guruhlash amalga oshiriladi va har bir guruhdagi 2022 Population ustunining o'rtacha qiymati hisoblanadi.

# %%
df.groupby('Continent')['2022 Population'].mean()
# Out:
# Continent
# Africa           2.503037e+07
# Asia             9.442767e+07
# Europe           1.486295e+07
# North America    1.500740e+07
# Oceania          1.958198e+06
# South America    3.120119e+07
# Name: 2022 Population, dtype: float64

# %% [markdown]
# #### Bu kodda, df.sort_index() usuli DataFrame ni avvalgi indeks bo'yicha tartiblaydi

# %%
df.sort_index()
# Out:
#      Rank CCA3  Country/Territory           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...
